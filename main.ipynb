# %%
from dobot_api import DobotApiFeedBack,DobotApiDashboard
import threading
from time import sleep
import re
import sys

# %% [markdown]
# constants

# %%
ip = '192.168.5.1'
dashboard_port = 29_999
feedback_port = 30_004

# %% [markdown]
# connect

# %%
dashboard = DobotApiDashboard(ip, dashboard_port)
feedback = DobotApiFeedBack(ip, feedback_port)

# %%
response = dashboard.RequestControl()
print(response)
# Out:
# Control Mode Is Not Tcp
# Control Mode Is Not Tcp

# %%
del dashboard
del feedback

# %%
from dobot_api import DobotApiFeedBack,DobotApiDashboard
import threading
from time import sleep
import re
import sys

ip = '192.168.5.1'
dashboard_port = 29_999
feedback_port = 30_004

dashboard = DobotApiDashboard(ip, dashboard_port)
feedback = DobotApiFeedBack(ip, feedback_port)

response = dashboard.RequestControl()
print(response)

# the output is as follows:
# Control Mode Is Not Tcp
# Control Mode Is Not Tcp
